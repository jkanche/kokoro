# %%
import json
import pandas as pd
import kuzu
import numpy as np
import hashlib

# %%
# Import graph
db_name = "onto_schub"

# %%
db = kuzu.Database(f'./{db_name}', buffer_pool_size=1024**3)
conn = kuzu.Connection(db)

# %%
def kuzu_execute(query, conn):
    res = conn.execute(query)
    df = res.get_as_df()
    return df.drop_duplicates()

# %%
def get_node_props(props = ["id", "name", "definition", "version", "source"], alias = "o"):
    modified = [f"{alias}.{prop} as {prop}" for prop in props]
    return ", ".join(modified)

# %% [markdown]
# ## Basic access queries

# %% [markdown]
# ### Get terms

# %%
onto_id = "CL:0002052"
osource = "Mondo Disease Ontology"
oversion = "v2022-03-01"

# %%
def to_string_params(props):
    params_str = []
    for k,v in props.items():
        params_str.append(f"{k}: '{v}'")
        
    return ", ".join(params_str)

# %% [markdown]
# ### Get terms by id

# %%
# just by id
params = {"id": onto_id}
query = f"MATCH (s:OntoTerm {{ {to_string_params(params)} }}) RETURN {get_node_props(alias='s')}"
kuzu_execute(query, conn)
# Out:
#            id                         name  \
# 0  CL:0002052  Fraction D precursor B cell
# 1  CL:0002052  Fraction D precursor B cell
# 2  CL:0002052  Fraction D precursor B cell
# 3  CL:0002052  fraction D precursor B cell
#
#                                           definition      version  \
# 0  A pre-B cell that is pre-BCR-negative, and the...  v2022-02-21
# 1  A pre-B cell that is pre-BCR-negative, and the...  v2022-03-01
# 2  A pre-B cell that is pre-BCR-negative, and the...      v3.39.1
# 3  A pre-B cell that is pre-BCR-negative, and the...  v2023-04-20
#
#                          source
# 0                        UBERON
# 1        Mondo Disease Ontology
# 2  Experimental Factor Ontology
# 3                 Cell Ontology

# %% [markdown]
# ### Get terms by id and source

# %%
# id and source
params = {"id": onto_id, "source": osource}
query = f"MATCH (s:OntoTerm {{ {to_string_params(params)} }}) RETURN {get_node_props(alias='s')}"
kuzu_execute(query, conn)
# Out:
#            id                         name  \
# 0  CL:0002052  Fraction D precursor B cell
#
#                                           definition      version  \
# 0  A pre-B cell that is pre-BCR-negative, and the...  v2022-03-01
#
#                    source
# 0  Mondo Disease Ontology

# %% [markdown]
# ### Get descendants

# %%
params = {"id": onto_id, "source": osource, "version":oversion}
query = f"MATCH (o:OntoTerm {{ {to_string_params(params)} }}) - [:child*1..20] -> (r:OntoTerm) RETURN {get_node_props(alias='r')}"
kuzu_execute(query, conn)
# Out:
#                     id                                      name  \
# 0           GO:0002009            morphogenesis of an epithelium
# 108         GO:0051179                              localization
# 124       CARO:0000000                         anatomical entity
# 592       CARO:0000003            connected anatomical structure
# 1278      CARO:0000006                material anatomical entity
# ...                ...                                       ...
# 218257      GO:0007498                      mesoderm development
# 218323  NCBITaxon:8287                             Sarcopterygii
# 218558      GO:0007399                nervous system development
# 218678      GO:0007398                      ectoderm development
# 218780      GO:0044260  cellular macromolecule metabolic process
#
#                                                definition      version  \
# 0       The process in which the anatomical structures...  v2022-03-01
# 108     Any process in which a cell, a substance, or a...  v2022-03-01
# 124                                                   NaN  v2022-03-01
# 592                                                   NaN  v2022-03-01
# 1278                                                  NaN  v2022-03-01
# ...                                                   ...          ...
# 218257  The process whose specific outcome is the prog...  v2022-03-01
# 218323                                                NaN  v2022-03-01
# 218558  The process whose specific outcome is the prog...  v2022-03-01
# 218678  The process whose specific outcome is the prog...  v2022-03-01
# 218780  The chemical reactions and pathways involving ...  v2022-03-01
#
#                         source
# 0       Mondo Disease Ontology
# 108     Mondo Disease Ontology
# 124     Mondo Disease Ontology
# 592     Mondo Disease Ontology
# 1278    Mondo Disease Ontology
# ...                        ...
# 218257  Mondo Disease Ontology
# 218323  Mondo Disease Ontology
# 218558  Mondo Disease Ontology
# 218678  Mondo Disease Ontology
# 218780  Mondo Disease Ontology
#
# [239 rows x 5 columns]

# %% [markdown]
# ### Get parents

# %%
params = {"id": onto_id, "source": osource, "version":oversion}
query = f"MATCH (o:OntoTerm {{ {to_string_params(params)} }}) <- [:parent*1..20] - (r:OntoTerm) RETURN {get_node_props(alias='r')}"
kuzu_execute(query, conn)
# Out:
#                   id                                      name  \
# 0         GO:0002009            morphogenesis of an epithelium
# 108       GO:0051179                              localization
# 124     CARO:0000000                         anatomical entity
# 592     CARO:0000003            connected anatomical structure
# 1278    CARO:0000006                material anatomical entity
# ...              ...                                       ...
# 218492    GO:0010467                           gene expression
# 218503  PATO:0000586                            increased size
# 218558    GO:0007399                nervous system development
# 218678    GO:0007398                      ectoderm development
# 218780    GO:0044260  cellular macromolecule metabolic process
#
#                                                definition      version  \
# 0       The process in which the anatomical structures...  v2022-03-01
# 108     Any process in which a cell, a substance, or a...  v2022-03-01
# 124                                                   NaN  v2022-03-01
# 592                                                   NaN  v2022-03-01
# 1278                                                  NaN  v2022-03-01
# ...                                                   ...          ...
# 218492  The process in which a gene's sequence is conv...  v2022-03-01
# 218503           A size quality which is relatively high.  v2022-03-01
# 218558  The process whose specific outcome is the prog...  v2022-03-01
# 218678  The process whose specific outcome is the prog...  v2022-03-01
# 218780  The chemical reactions and pathways involving ...  v2022-03-01
#
#                         source
# 0       Mondo Disease Ontology
# 108     Mondo Disease Ontology
# 124     Mondo Disease Ontology
# 592     Mondo Disease Ontology
# 1278    Mondo Disease Ontology
# ...                        ...
# 218492  Mondo Disease Ontology
# 218503  Mondo Disease Ontology
# 218558  Mondo Disease Ontology
# 218678  Mondo Disease Ontology
# 218780  Mondo Disease Ontology
#
# [239 rows x 5 columns]
